# %%
 #My Agent project #S
 
 
# pip install google-generativeai
 
import subprocess
import webbrowser
from datetime import datetime
#import google.generativeai as genai
 
 
whoami_op = subprocess.run(["whoami"], capture_output= True, text = True)
user_name = whoami_op.stdout.split("\\")[1].strip()
 
 
print(f'''
 
{(10+(len(user_name)))*"="}
= Hello {user_name} =
{(10+(len(user_name)))*"="}
 
''')
 
 
def log(txt):
    with open("logger.txt", "a") as log_file:
        log_file.write(f'{datetime.now().strftime('%Y-%m-%d %H:%M:%S')} {txt}\n')
 
 
def query_llm(query):
    API_KEY = "AIzaSyDjRPjU3O-g5WBFdYUkt4WiXBgrvjhh5Po"
    genai.configure(api_key=API_KEY)
 
    generation_config = {
        "temperature": 1,
        "max_output_tokens": 100,
        "response_mime_type": "text/plain",
    }
 
    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        generation_config=generation_config
    )
 
    chat_session = model.start_chat(
        history=[
            {
            "role": "user",
                "parts": [
                    "you are my assistant, answer my queries and no need to explain much",
                ],
            },
        ]
    )
 
    response = chat_session.send_message(query)
    return response.candidates[0].content.parts[0].text
 
 
exit_triggers = ["bye", "quit", "exit", "tata"]
app_dict = {"notepad": "notepad.exe", "fm": "explorer.exe"}
 
while True:
    user_inp = input(f"\n[Sepi] How may I help you {user_name}? \n-> ")
    log(f'user input - {user_inp}')
 
    if exit_triggers.count(user_inp.lower()):
        log("quit action")
        print(f"Have a nice day {user_name}, tata 🫡")
        break
 
    try:
        cmd = user_inp.split(" ")[0].lower().strip()
 
        if cmd == "open":
            app_name = user_inp.split(" ")[1].lower()
            if app_dict.get(app_name):
                print(f"opening app - {app_name}")
                log(f"opening app - {app_name}")
                subprocess.run([app_dict.get(app_name)])
            else:
                print(f"{app_name} - Not installed")
                log(f"{app_name} - Not installed")
 
        elif cmd == "web":
            link = " ".join(user_inp.split(" ")[1:])
            print(f"opening link - {link}")
            log(f"opening link - {link}")
            webbrowser.open(link)
 
        elif cmd == "sepi":
            query = " ".join(user_inp.split(" ")[1:])
            log(f'Sepi is looking for : {query}')
            ans = query_llm(query)
            print(f'\n[Sepi] {ans}')
       
        else:
            print("Invalid user input")
 
    except Exception as e:
        print("Error while handling user input, error: ", e)
        log("Error while handling user input")
# Out:
# ...
# = Hello plangote =
# ...
#
#
# chrome - Not installed
# Invalid user input
# opening app - fm
# Have a nice day plangote, tata 🫡
